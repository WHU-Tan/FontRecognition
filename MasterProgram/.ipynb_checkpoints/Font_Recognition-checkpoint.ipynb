# %%
from matplotlib.pyplot import imshow
import matplotlib.cm as cm
import matplotlib.pylab as plt
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import PIL
from PIL import ImageFilter
import cv2
import itertools
import random
import keras
import imutils
from imutils import paths
import os
from keras import optimizers
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras import callbacks
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D , UpSampling2D ,Conv2DTranspose
from keras import backend as K

import flask,json
from flask import request

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def pil_image(img_path):
    pil_im =PIL.Image.open(img_path).convert('L')
    pil_im=pil_im.resize((105,105))
    #imshow(np.asarray(pil_im))
    return pil_im
# Out:
# C:\Users\53423

# %% [markdown]
# # Augumentation Steps
# 1) Noise
# 2) Blur
# 3) Perpective Rotation
# 4) Shading
# 5) Variable Character Spacing
# 6) Variable Aspect Ratio

# %%
def noise_image(pil_im):
    # Adding Noise to image
    img_array = np.asarray(pil_im)
    mean = 0.0   # some constant
    std = 5   # some constant (standard deviation)
    noisy_img = img_array + np.random.normal(mean, std, img_array.shape)
    noisy_img_clipped = np.clip(noisy_img, 0, 255)
    noise_img = PIL.Image.fromarray(np.uint8(noisy_img_clipped)) # output
    #imshow((noisy_img_clipped ).astype(np.uint8))
    noise_img=noise_img.resize((105,105))
    return noise_img

# %%
def blur_image(pil_im):
    #Adding Blur to image 
    blur_img = pil_im.filter(ImageFilter.GaussianBlur(radius=3)) # ouput
    #imshow(blur_img)
    blur_img=blur_img.resize((105,105))
    return blur_img

# %%
def affine_rotation(img):
    
    #img=cv2.imread(img_path,0)
    rows, columns = img.shape

    point1 = np.float32([[10, 10], [30, 10], [10, 30]])
    point2 = np.float32([[20, 15], [40, 10], [20, 40]])

    A = cv2.getAffineTransform(point1, point2)

    output = cv2.warpAffine(img, A, (columns, rows))
    affine_img = PIL.Image.fromarray(np.uint8(output)) # affine rotated output
    #imshow(output)
    affine_img=affine_img.resize((105,105))
    return affine_img

# %%
def gradient_fill(image):
    #image=cv2.imread(img_path,0)
    laplacian = cv2.Laplacian(image,cv2.CV_64F)
    laplacian = cv2.resize(laplacian, (105, 105))
    return laplacian

# %% [markdown]
# ## Preparing Dataset

# %%
data_path = "/font_patch"
data=[]
labels=[]
imagePaths = sorted(list(paths.list_images(data_path)))
random.seed(42)
random.shuffle(imagePaths)

# %%
def conv_label(label):
    if label == 'Lato':
        return 0
    elif label == 'Raleway':
        return 1
    elif label == 'Roboto':
        return 2
    elif label == 'Sansation':
        return 3
    elif label == 'Walkway':
        return 4

# %%
augument=["blur","noise","affine","gradient"]
a=itertools.combinations(augument, 4)

for i in list(a): 
    print(list(i))
# Out:
# ['blur', 'noise', 'affine', 'gradient']

# %%
counter=0
for imagePath in imagePaths:
    label = imagePath.split(os.path.sep)[-2]
    label = conv_label(label)
    pil_img = pil_image(imagePath)
    #imshow(pil_img)
    
    # Adding original image
    org_img = img_to_array(pil_img)
    #print(org_img.shape)
    data.append(org_img)
    labels.append(label)
    
    augument=["noise","blur","affine","gradient"]
    for l in range(0,len(augument)):
    
        a=itertools.combinations(augument, l+1)

        for i in list(a): 
            combinations=list(i)
            print(len(combinations))
            temp_img = pil_img
            for j in combinations:
            
                if j == 'noise':
                    # Adding Noise image
                    temp_img = noise_image(temp_img)
                    
                elif j == 'blur':
                    # Adding Blur image
                    temp_img = blur_image(temp_img)
                    #imshow(blur_img)
                    
    
                elif j == 'affine':
                    open_cv_affine = np.array(pil_img)
                    # Adding affine rotation image
                    temp_img = affine_rotation(open_cv_affine)

                elif j == 'gradient':
                    open_cv_gradient = np.array(pil_img)
                    # Adding gradient image
                    temp_img = gradient_fill(open_cv_gradient)
  
            temp_img = img_to_array(temp_img)
            data.append(temp_img)
            labels.append(label)
# Out:
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4
# 1
# 1
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 4

# %%
data = np.asarray(data, dtype="float") / 255.0
labels = np.array(labels)
print("Success")
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.25, random_state=42)
# Out:
# Success

# %%
# convert the labels from integers to vectors
trainY = to_categorical(trainY, num_classes=5)
testY = to_categorical(testY, num_classes=5)

# %%
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,horizontal_flip=True)

# %%
K.set_image_data_format('channels_last')

# %%
from keras.models import load_model
model = load_model('/model/model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\53423\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\53423\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\53423\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
early_stopping=callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min')

filepath="C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5"

checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks_list = [early_stopping,checkpoint]
batch_size = 128
epochs = 50

# %%
model.fit(trainX, trainY,shuffle=True,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(testX, testY),
          callbacks=callbacks_list)
# Out:
# Train on 468 samples, validate on 156 samples
# Epoch 1/50
# 468/468 [==============================] - 289s 617ms/step - loss: 2.5867e-06 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9487
#
# Epoch 00001: val_loss improved from 0.01377 to 0.01365, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 2/50
# 468/468 [==============================] - 271s 578ms/step - loss: 5.1558e-07 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9551
#
# Epoch 00002: val_loss improved from 0.01365 to 0.01302, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 3/50
# 468/468 [==============================] - 269s 575ms/step - loss: 3.1489e-06 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9615
#
# Epoch 00003: val_loss improved from 0.01302 to 0.01220, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 4/50
# 468/468 [==============================] - 269s 574ms/step - loss: 1.9533e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9744
#
# Epoch 00004: val_loss improved from 0.01220 to 0.01086, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 5/50
# 468/468 [==============================] - 280s 598ms/step - loss: 1.0740e-06 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9744
#
# Epoch 00005: val_loss improved from 0.01086 to 0.00998, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 6/50
# 468/468 [==============================] - 277s 592ms/step - loss: 2.3855e-06 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9744
#
# Epoch 00006: val_loss improved from 0.00998 to 0.00905, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 7/50
# 468/468 [==============================] - 280s 599ms/step - loss: 8.3438e-06 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9744
#
# Epoch 00007: val_loss improved from 0.00905 to 0.00823, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 8/50
# 468/468 [==============================] - 285s 609ms/step - loss: 8.6650e-07 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9808
#
# Epoch 00008: val_loss improved from 0.00823 to 0.00754, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 9/50
# 468/468 [==============================] - 281s 601ms/step - loss: 9.4184e-07 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9872
#
# Epoch 00009: val_loss improved from 0.00754 to 0.00678, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 10/50
# 468/468 [==============================] - 281s 601ms/step - loss: 3.6246e-07 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9872
#
# Epoch 00010: val_loss improved from 0.00678 to 0.00601, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 11/50
# 468/468 [==============================] - 280s 599ms/step - loss: 1.0643e-07 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9872
#
# Epoch 00011: val_loss improved from 0.00601 to 0.00526, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 12/50
# 468/468 [==============================] - 283s 604ms/step - loss: 2.8167e-07 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9872
#
# Epoch 00012: val_loss improved from 0.00526 to 0.00455, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 13/50
# 468/468 [==============================] - 281s 601ms/step - loss: 4.8249e-06 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9872
#
# Epoch 00013: val_loss improved from 0.00455 to 0.00383, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 14/50
# 468/468 [==============================] - 278s 595ms/step - loss: 2.7317e-07 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9936
#
# Epoch 00014: val_loss improved from 0.00383 to 0.00325, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 15/50
# 468/468 [==============================] - 280s 598ms/step - loss: 5.8217e-07 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9936
#
# Epoch 00015: val_loss improved from 0.00325 to 0.00275, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 16/50
# 468/468 [==============================] - 276s 590ms/step - loss: 8.1915e-06 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9936
#
# Epoch 00016: val_loss improved from 0.00275 to 0.00240, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 17/50
# 468/468 [==============================] - 272s 581ms/step - loss: 3.3200e-06 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9936
#
# Epoch 00017: val_loss improved from 0.00240 to 0.00194, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 18/50
# 468/468 [==============================] - 278s 594ms/step - loss: 2.2732e-06 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9936
#
# Epoch 00018: val_loss improved from 0.00194 to 0.00160, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 19/50
# 468/468 [==============================] - 270s 577ms/step - loss: 1.5771e-06 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9936
#
# Epoch 00019: val_loss improved from 0.00160 to 0.00134, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 20/50
# 468/468 [==============================] - 275s 588ms/step - loss: 5.0687e-07 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9936
#
# Epoch 00020: val_loss improved from 0.00134 to 0.00111, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 21/50
# 468/468 [==============================] - 272s 582ms/step - loss: 6.0659e-07 - accuracy: 1.0000 - val_loss: 9.0938e-04 - val_accuracy: 0.9936
#
# Epoch 00021: val_loss improved from 0.00111 to 0.00091, saving model to C:/Users/53423/Desktop/work/DIP/project/Font_Recognition-DeepFont-master/Font_Recognition-DeepFont-master/model/model.h5
# Epoch 22/50
# 128/468 [=======>......................] - ETA: 3:05 - loss: 4.1897e-07 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-d05af1927220> in <module>
#       4           verbose=1,
#       5           validation_data=(testX, testY),
# ----> 6           callbacks=callbacks_list)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
score = model.evaluate(testX, testY, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.0009296401508319646
# Test accuracy: 0.9935897588729858

# %%
from keras.models import load_model
model = load_model('/model/model.h5')

# %%
score = model.evaluate(testX, testY, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.0009296401508319646
# Test accuracy: 0.9935897588729858

# %%
img_path="/sample/sample.jpg"
pil_im =PIL.Image.open(img_path).convert('L')
pil_im=blur_image(pil_im)
org_img = img_to_array(pil_im)

# %%
def rev_conv_label(label):
    if label == 0 :
        return 'Lato'
    elif label == 1:
        return 'Raleway'
    elif label == 2 :
        return 'Roboto'
    elif label == 3 :
        return 'Sansation'
    elif label == 4:
        return 'Walkway'

# %%
data=[]
data.append(org_img)
data = np.asarray(data, dtype="float") / 255.0

# %%
y = model.predict_classes(data)

# %%
label = rev_conv_label(int(y[0]))
fig, ax = plt.subplots(1)
ax.imshow(pil_im, interpolation='nearest', cmap=cm.gray)
ax.text(5, 5, label , bbox={'facecolor': 'white', 'pad': 10})
plt.show()

# %%
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\53423\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
